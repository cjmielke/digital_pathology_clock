# %%
clinical = pd.read_csv('/home/cosmo/tcga_pathology_aging_clock/lung/clinical.tsv', sep='\t')#.replace("'--", np.nan)
clinical.head()
# Out:
#                                 case_id    case_submitter_id project_id  \
# 0  00021f80-e72d-4c18-9e36-7959060e1fe1  GENIE-MSK-P-0000344  GENIE-MSK
# 1  00048fa6-4318-42ef-9709-7dedb0d938b3               AD2413      FM-AD
# 2  000c3acf-e915-4c5f-bbc3-13031797024c      GENIE-JHU-00450  GENIE-JHU
# 3  000da8b9-7511-4097-ae68-2c0f0cfe6f85              AD11350      FM-AD
# 4  000e0a5a-82fc-45a2-ab70-b1dcead463a7              AD10520      FM-AD
#
#   age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# 0          '--               '--            '--                   '--
# 1          '--               '--            '--                   '--
# 2          '--               '--            '--                   '--
# 3          '--               '--            '--                   '--
# 4          '--               '--            '--                   '--
#
#   country_of_residence_at_enrollment days_to_birth days_to_death  ...  \
# ...

# %%
clinical.describe()
# Out:
#                                      case_id  case_submitter_id project_id  \
# count                                  13515              13515      13515
# unique                                 12262              12262         19
# top     e506251d-4072-4479-b2ce-5c75387dc7fc  HCM-BROD-0007-C49      FM-AD
# freq                                      18                 18       3769
#
#        age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# count         13515             13515          13515                 13515
# unique           54                 2              7                     1
# top             '--               '--            '--                   '--
# freq          11314             13320          13285                 13515
#
#        country_of_residence_at_enrollment days_to_birth days_to_death  ...  \
# count                               13515         13515         13515  ...
# ...

# %%
dayCols = [c for c in clinical.columns if 'days' in c]

# %%
clinical[dayCols].replace("'--", np.nan).describe().T
# Out:
#                                   count unique     top  freq
# days_to_birth                      9464   1392  -24837   375
# days_to_death                      1009    452     372    11
# days_to_best_overall_response        24     11     130     3
# days_to_diagnosis                  2095      1       0  2095
# days_to_last_follow_up             2103    864  1825.0    26
# days_to_last_known_disease_status   318    263   355.0     4
# days_to_recurrence                   16     16   904.0     1
# days_to_treatment_end                33     24     352     3
# days_to_treatment_start              48     30      19     5

# %%
[c for c in clinical.columns if 'age' in c.lower()]
# Out:
# ['age_at_index',
#  'age_is_obfuscated',
#  'age_at_diagnosis',
#  'ajcc_clinical_stage',
#  'ajcc_pathologic_stage',
#  'ann_arbor_clinical_stage',
#  'ann_arbor_pathologic_stage',
#  'cog_liver_stage',
#  'cog_renal_stage',
#  'enneking_msts_stage',
#  'esophageal_columnar_dysplasia_degree',
#  'esophageal_columnar_metaplasia_present',
#  'figo_stage',
#  'gastric_esophageal_junction_involvement',
#  'igcccg_stage',
#  'inrg_stage',
#  'inss_stage',
#  'irs_stage',
#  'iss_stage',
#  'masaoka_stage',
#  'tumor_stage',
#  'therapeutic_agents']

# %%
clinical[clinical.age_at_index!="'--"]
# Out:
#                                     case_id case_submitter_id project_id  \
# 25     005669e5-1a31-45fb-ae97-9d450e74e7cb      TCGA-77-A5GF  TCGA-LUSC
# 26     005669e5-1a31-45fb-ae97-9d450e74e7cb      TCGA-77-A5GF  TCGA-LUSC
# 36     0075437e-ba1a-46be-86d6-9773209a2b5e      TCGA-62-A471  TCGA-LUAD
# 37     0075437e-ba1a-46be-86d6-9773209a2b5e      TCGA-62-A471  TCGA-LUAD
# 45     009be09b-f9f6-43b7-8f45-4a648f8123ce      TCGA-67-3773  TCGA-LUAD
# ...                                     ...               ...        ...
# 13497  ffb0c0b7-165e-4439-b3e6-62431f40b7fe      TCGA-44-3398  TCGA-LUAD
# 13498  ffb53b81-c1ed-473c-bdcd-b325b02e22ae      TCGA-98-8020  TCGA-LUSC
# 13499  ffb53b81-c1ed-473c-bdcd-b325b02e22ae      TCGA-98-8020  TCGA-LUSC
# 13500  ffb83f21-06d9-4e52-a2d0-e85c13f4037f      TCGA-39-5039  TCGA-LUSC
# 13501  ffb83f21-06d9-4e52-a2d0-e85c13f4037f      TCGA-39-5039  TCGA-LUSC
#
#       age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# ...

# %%
clinical.age_at_index.value_counts()
# Out:
# age_at_index
# '--    11314
# 70       116
# 73       104
# 68        98
# 74        92
# 69        88
# 65        88
# 67        87
# 71        86
# 59        82
# 60        80
# 66        78
# 72        76
# 63        74
# 76        72
# 64        71
# 75        70
# 61        67
# 62        64
# 57        54
# 58        53
# 77        52
# 52        50
# 56        47
# 79        38
# 81        38
# 78        36
# 54        36
# 55        32
# 51        25
# 80        24
# 53        24
# 84        20
# 50        20
# 83        16
# 49        16
# 40        15
# 46        14
# 47        14
# 45        12
# 48        10
# 42        10
# 41        10
# 85         8
# 44         8
# 82         6
# 87         4
# 39         4
# 86         2
# 88         2
# 38         2
# 33         2
# 90         2
# 43         2
# Name: count, dtype: int64

# %%
clinical.days_to_diagnosis.value_counts()
# Out:
# days_to_diagnosis
# '--    11420
# 0       2095
# Name: count, dtype: int64

# %%
for dc in dayCols:
    s=clinical[dc].value_counts()
    print(s)
# Out:
# days_to_birth
# '--       4051
# -24837     375
# -26298     332
# -23376     294
# -21915     290
#           ...
# -27161       1
# -21151       1
# -25374       1
# -21005       1
# -23162       1
# Name: count, Length: 1393, dtype: int64
# days_to_death
# '--     12506
# 372        11
# 94          8
# 407         7
# 111         7
#         ...
# 317         1
# 205         1
# -1          1
# 849         1
# 1849        1
# Name: count, Length: 453, dtype: int64
# days_to_best_overall_response
# '--    13491
# 130        3
# 134        3
# 785        3
# 75         2
# 573        2
# 112        2
# 651        2
# 636        2
# 148        2
# 588        2
# 265        1
# Name: count, dtype: int64
# days_to_diagnosis
# '--    11420
# 0       2095
# Name: count, dtype: int64
# days_to_last_follow_up
# '--       11412
# 1825.0       26
# 0.0          21
# 61.0         16
# 30.0         15
#           ...
# 1795.0        1
# 295.0         1
# 1821.0        1
# 345.0         1
# ...

# %%
clinical.days_to_diagnosis.dropna()
# Out:
# 25       0
# 26       0
# 36       0
# 37       0
# 45       0
#         ..
# 13497    0
# 13498    0
# 13499    0
# 13500    0
# 13501    0
# Name: days_to_diagnosis, Length: 2095, dtype: object

# %%
[c for c in clinical.columns if 'days' in c]
# Out:
# ['days_to_birth',
#  'days_to_death',
#  'days_to_best_overall_response',
#  'days_to_diagnosis',
#  'days_to_last_follow_up',
#  'days_to_last_known_disease_status',
#  'days_to_recurrence',
#  'days_to_treatment_end',
#  'days_to_treatment_start']

# %%
clinical.replace("'--", np.nan).days_to_diagnosis.dropna()
# Out:
# 25       0
# 26       0
# 36       0
# 37       0
# 45       0
#         ..
# 13497    0
# 13498    0
# 13499    0
# 13500    0
# 13501    0
# Name: days_to_diagnosis, Length: 2095, dtype: object

# %%
clinical.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_19217/1346572597.py in ?()
# ----> 1 clinical.summary()
#
# ~/miniconda3/envs/pathology_clock/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6198             and name not in self._accessors
#    6199             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200         ):
#    6201             return self[name]
# -> 6202         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'summary'
